# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.1'

# %%
df = pd.read_csv('./homework_w1/green_tripdata_2019-10.csv')
# Out:
# /tmp/ipykernel_6025/4010270101.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./homework_w1/green_tripdata_2019-10.csv')

# %%
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-10-01 00:26:02   2019-10-01 00:39:58
# 1            1.0  2019-10-01 00:18:11   2019-10-01 00:22:38
# 2            1.0  2019-10-01 00:09:31   2019-10-01 00:24:47
# 3            1.0  2019-10-01 00:37:40   2019-10-01 00:41:49
# 4            2.0  2019-10-01 00:08:13   2019-10-01 00:17:56
# ...          ...                  ...                   ...
# 476381       NaN  2019-10-31 23:30:00   2019-11-01 00:00:00
# 476382       NaN  2019-10-31 23:03:00   2019-10-31 23:24:00
# 476383       NaN  2019-10-31 23:02:00   2019-10-31 23:23:00
# 476384       NaN  2019-10-31 23:42:00   2019-10-31 23:56:00
# 476385       NaN  2019-10-31 23:23:00   2019-10-31 23:56:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           112           196
# 1                       N         1.0            43           263
# ...

# %%
print(pd.io.sql.get_schema(df, name='green_tripdata_2019-10.csv'))
# Out:
# CREATE TABLE "green_tripdata_2019-10.csv" (
# "VendorID" REAL,
#   "lpep_pickup_datetime" TEXT,
#   "lpep_dropoff_datetime" TEXT,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" REAL,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" REAL,
#   "trip_type" REAL,
#   "congestion_surcharge" REAL
# )

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df['lpep_pickup_date'] = df['lpep_pickup_datetime'].dt.date
df['lpep_dropoff_date'] = df['lpep_dropoff_datetime'].dt.date
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-10-01 00:26:02   2019-10-01 00:39:58
# 1            1.0  2019-10-01 00:18:11   2019-10-01 00:22:38
# 2            1.0  2019-10-01 00:09:31   2019-10-01 00:24:47
# 3            1.0  2019-10-01 00:37:40   2019-10-01 00:41:49
# 4            2.0  2019-10-01 00:08:13   2019-10-01 00:17:56
# ...          ...                  ...                   ...
# 476381       NaN  2019-10-31 23:30:00   2019-11-01 00:00:00
# 476382       NaN  2019-10-31 23:03:00   2019-10-31 23:24:00
# 476383       NaN  2019-10-31 23:02:00   2019-10-31 23:23:00
# 476384       NaN  2019-10-31 23:42:00   2019-10-31 23:56:00
# 476385       NaN  2019-10-31 23:23:00   2019-10-31 23:56:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           112           196
# 1                       N         1.0            43           263
# ...

# %%
#Question4
specific_date = pd.to_datetime('2019-10-18').date()  # Data da confrontare
df_test1 = df[df['lpep_pickup_date'] == specific_date]
df_test1 = df_test1[df_test1['lpep_dropoff_date'] == specific_date]
df_test1
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 216611       2.0  2019-10-18 00:00:40   2019-10-18 00:04:41
# 216664       2.0  2019-10-18 00:00:10   2019-10-18 00:13:16
# 216864       2.0  2019-10-18 00:01:17   2019-10-18 00:09:42
# 216935       2.0  2019-10-18 00:00:12   2019-10-18 00:27:39
# 216942       2.0  2019-10-18 00:12:39   2019-10-18 00:13:15
# ...          ...                  ...                   ...
# 434202       NaN  2019-10-18 23:09:00   2019-10-18 23:23:00
# 434203       NaN  2019-10-18 23:11:00   2019-10-18 23:22:00
# 434204       NaN  2019-10-18 23:46:00   2019-10-18 23:56:00
# 434207       NaN  2019-10-18 23:01:00   2019-10-18 23:22:00
# 434212       NaN  2019-10-18 23:03:00   2019-10-18 23:15:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 216611                  N         1.0           145           112
# 216664                  N         1.0            95           215
# ...

# %%
max_value = df['trip_distance'].max()
max_value

giorno = df.loc[df['trip_distance'].idxmax()]
giorno
# Out:
# VendorID                                 2.0
# lpep_pickup_datetime     2019-10-31 23:23:41
# lpep_dropoff_datetime    2019-11-01 13:01:07
# store_and_fwd_flag                         N
# RatecodeID                               5.0
# PULocationID                             129
# DOLocationID                             265
# passenger_count                          1.0
# trip_distance                         515.89
# fare_amount                            100.0
# extra                                   2.75
# mta_tax                                  0.0
# tip_amount                               0.0
# tolls_amount                             0.0
# ehail_fee                                NaN
# improvement_surcharge                    0.3
# total_amount                          103.05
# payment_type                             2.0
# trip_type                                1.0
# congestion_surcharge                     0.0
# lpep_pickup_date                  2019-10-31
# ...

# %%
print(pd.io.sql.get_schema(df, name='green_tripdata_2019-01.csv'))
# Out:
# CREATE TABLE "green_tripdata_2019-01.csv" (
# "VendorID" REAL,
#   "lpep_pickup_datetime" TIMESTAMP,
#   "lpep_dropoff_datetime" TIMESTAMP,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" REAL,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" REAL,
#   "trip_type" REAL,
#   "congestion_surcharge" REAL,
#   "lpep_pickup_date" DATE,
#   "lpep_dropoff_date" DATE
# )

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='green_taxi_data', con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" FLOAT(53),
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type FLOAT(53),
# 	trip_type FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('./homework_w1/green_tripdata_2019-10.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
print((df.lpep_pickup_datetime=='2019-09-18')==True)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Name: lpep_pickup_datetime, Length: 100000, dtype: bool

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2019-10-01 00:26:02   2019-10-01 00:39:58                  N
# 1         1  2019-10-01 00:18:11   2019-10-01 00:22:38                  N
# 2         1  2019-10-01 00:09:31   2019-10-01 00:24:47                  N
# 3         1  2019-10-01 00:37:40   2019-10-01 00:41:49                  N
# 4         2  2019-10-01 00:08:13   2019-10-01 00:17:56                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           112           196                1           5.88
# 1           1            43           263                1           0.80
# 2           1           255           228                2           7.50
# 3           1           181           181                1           0.90
# 4           1            97           188                1           2.52
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.head(n=0)
# Out:
# Empty DataFrame
# Columns: [VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge]
# Index: []

# %%
df.to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 1000

# %%
# %time df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 2.7 s, sys: 17.7 ms, total: 2.72 s
# Wall time: 5.26 s
# 1000

# %%
from time import time

# %%
while True: 
    t_start = time()

    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk, took 5.426 second
# inserted another chunk, took 5.467 second
# /tmp/ipykernel_6025/1406748514.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk, took 5.357 second
# inserted another chunk, took 3.467 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[37], line 4
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next(df_iter)
#       6     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#       7     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1668, in TextFileReader.__next__(self)
#    1666 def __next__(self) -> DataFrame:
#    1667     try:
# -> 1668         return self.get_chunk()
# ...

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv

# %%
df_zones = pd.read_csv('./homework_w1/taxi_zone_lookup.csv')

# %%
df_zones

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')

# %%
merged_df = pd.merge(df, df_zones, on='LocationID')  # Merge sulla colonna comune 'id'
